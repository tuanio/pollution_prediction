# %% [markdown]
# # Things to do
#     - add humidity column
#     - add weekday column
#     - one hot encoder cbwd and weekday columns
#     - fill NaN with not NaN before
#     - outliers
#     - add past data columns

# %%
import pandas as pd
import numpy as np
from math import exp, isnan
from datetime import datetime
from matplotlib import pyplot as plt
from plotly import express as px
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0   1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1   2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2   3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3   4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4   5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0

# %% [markdown]
# ## Add humidity column

# %%
def cal(temp, dewp):
    return 100*(exp((17.625*dewp)/(243.04+dewp))/exp((17.625*temp)/(243.04+temp)))
df['hum'] = [cal(temp, dewp) for temp, dewp in zip(df['TEMP'], df['DEWP'])]

# %% [markdown]
# ## Add weekday column

# %%
weekday = ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']
tmp = []
for i, j, k in zip(df['day'], df['month'], df['year']):
    date = weekday[datetime.strptime(str('{}/{}/{}'.format(i, j, k)), '%d/%m/%Y').weekday()]
    tmp.append(date)
df['weekday'] = tmp

# %% [markdown]
# ## One Hot Encoder cbwd and weekday columns

# %%
df = pd.get_dummies(df)

# %% [markdown]
# ## Fill NaN with not NaN before

# %%
df['pm2.5'].isna().sum()
# Out:
# 2067

# %%
pre = -1
tmp = []
for i in df['pm2.5']:
    if not isnan(i):
        pre = i
    tmp.append(pre)
df['pm2.5'] = tmp
df = df[df['pm2.5'] != -1]

# %%
df
# Out:
#           No  year  month  day  hour       pm2.5       DEWP      TEMP    PRES  \
# 19        25  2010      1    2     0  129.000000 -16.000000 -4.000000  1020.0
# 20        26  2010      1    2     1  148.000000 -15.000000 -4.000000  1020.0
# 21        27  2010      1    2     2  159.000000 -11.000000 -5.000000  1021.0
# 22        28  2010      1    2     3  181.000000  -7.000000 -5.000000  1022.0
# 23        29  2010      1    2     4  138.000000  -7.000000 -5.000000  1022.0
# ...      ...   ...    ...  ...   ...         ...        ...       ...     ...
# 43793  43824  2015      1    1     1   13.710462 -21.226689 -2.995268  1034.0
# 43794  43824  2015      1    1     2    4.884109 -22.358063 -4.123623  1034.0
# 43795  43824  2015      1    1     3   15.521942 -21.426143 -2.927048  1034.0
# 43796  43824  2015      1    1     4    1.630938 -22.480836 -4.119015  1034.0
# 43797  43824  2015      1    1     5   17.858858 -21.580474 -2.844533  1034.0
#
#           Iws  ...    TEMP_1    TEMP_2    TEMP_3    TEMP_4    TEMP_5   Iws_1  \
# 19       1.79  ... -5.000000 -5.000000 -5.000000 -5.000000 -4.000000    0.89
# 20       2.68  ... -4.000000 -5.000000 -5.000000 -5.000000 -5.000000    1.79
# 21       3.57  ... -4.000000 -4.000000 -5.000000 -5.000000 -5.000000    2.68
# 22       5.36  ... -5.000000 -4.000000 -4.000000 -5.000000 -5.000000    3.57
# 23       6.25  ... -5.000000 -5.000000 -4.000000 -4.000000 -5.000000    5.36
# ...       ...  ...       ...       ...       ...       ...       ...     ...
# 43793  249.85  ... -4.111599 -3.000000 -4.000000 -3.000000 -3.000000  249.85
# 43794  249.85  ... -2.995268 -4.111599 -3.000000 -4.000000 -3.000000  249.85
# 43795  249.85  ... -4.123623 -2.995268 -4.111599 -3.000000 -4.000000  249.85
# 43796  249.85  ... -2.927048 -4.123623 -2.995268 -4.111599 -3.000000  249.85
# 43797  249.85  ... -4.119015 -2.927048 -4.123623 -2.995268 -4.111599  249.85
#
#         Iws_2   Iws_3   Iws_4   Iws_5
# 19       2.68    1.79    0.89    1.79
# 20       0.89    2.68    1.79    0.89
# 21       1.79    0.89    2.68    1.79
# 22       2.68    1.79    0.89    2.68
# 23       3.57    2.68    1.79    0.89
# ...       ...     ...     ...     ...
# 43793  249.85  246.72  242.70  237.78
# 43794  249.85  249.85  246.72  242.70
# 43795  249.85  249.85  249.85  246.72
# 43796  249.85  249.85  249.85  249.85
# 43797  249.85  249.85  249.85  249.85
#
# [43779 rows x 44 columns]

# %% [markdown]
# ## Outliers

# %%
dic = {}
for day, month, year, hour, pm25 in zip(df['day'], df['month'], df['year'], df['hour'], df['pm2.5']):
    dic[datetime.strptime(str('{}/{}/{} {}:00'.format(day, month, year, hour)), '%d/%m/%Y %H:%M')] = pm25

# %%
outlier_df = pd.DataFrame.from_dict(dic, orient='index', columns=['Value'])

# %%
outlier_df.plot()
plt.show()

# %%
df = df[df['pm2.5'] <= 600]

# %% [markdown]
# ## Add past data columns

# %%
need_shift = ['pm2.5', 'DEWP', 'TEMP', 'Iws']
for var in need_shift:
    for i in range(1, 6):
        key = var + '_' + str(i)
        df[key] = df[var].shift(periods=i)
df.dropna(inplace=True)
# Out:
# <ipython-input-33-25b40abb8361>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[key] = df[var].shift(periods=i)
# <ipython-input-33-25b40abb8361>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['No', 'year', 'month', 'day', 'hour', 'pm2.5', 'DEWP', 'TEMP', 'PRES',
#        'Iws', 'Is', 'Ir', 'hum', 'cbwd_NE', 'cbwd_NW', 'cbwd_SE', 'cbwd_cv',
#        'weekday_Fri', 'weekday_Mon', 'weekday_Sat', 'weekday_Sun',
#        'weekday_Thu', 'weekday_Tue', 'weekday_Wed', 'pm2.5_1', 'pm2.5_2',
#        'pm2.5_3', 'pm2.5_4', 'pm2.5_5', 'DEWP_1', 'DEWP_2', 'DEWP_3', 'DEWP_4',
#        'DEWP_5', 'TEMP_1', 'TEMP_2', 'TEMP_3', 'TEMP_4', 'TEMP_5', 'Iws_1',
#        'Iws_2', 'Iws_3', 'Iws_4', 'Iws_5'],
#       dtype='object')

# %%
features = list(df.columns[8:])
predicts = list(df.columns[5:8])

# %%
predicts
# Out:
# ['pm2.5', 'DEWP', 'TEMP']

# %%
X = df[features]
y = df[predicts]

# %%
X
# Out:
#          PRES     Iws  Is  Ir        hum  cbwd_NE  cbwd_NW  cbwd_SE  cbwd_cv  \
# 24     1022.0    7.14   3   0  92.629771        0        0        1        0
# 25     1023.0    8.93   4   0  92.629771        0        0        1        0
# 26     1024.0   10.72   0   0  85.857955        0        0        1        0
# 27     1024.0   12.51   0   0  85.746866        0        0        1        0
# 28     1025.0   14.30   0   0  85.857955        0        0        1        0
# ...       ...     ...  ..  ..        ...      ...      ...      ...      ...
# 43793  1034.0  249.85   0   0  23.535657        0        1        0        0
# 43794  1034.0  249.85   0   0  23.535657        0        1        0        0
# 43795  1034.0  249.85   0   0  23.535657        0        1        0        0
# 43796  1034.0  249.85   0   0  23.535657        0        1        0        0
# 43797  1034.0  249.85   0   0  23.535657        0        1        0        0
#
#        weekday_Fri  ...    TEMP_1    TEMP_2    TEMP_3    TEMP_4    TEMP_5  \
# 24               1  ... -5.000000 -5.000000 -5.000000 -4.000000 -4.000000
# 25               1  ... -6.000000 -5.000000 -5.000000 -5.000000 -4.000000
# 26               1  ... -6.000000 -6.000000 -5.000000 -5.000000 -5.000000
# 27               1  ... -5.000000 -6.000000 -6.000000 -5.000000 -5.000000
# 28               1  ... -6.000000 -5.000000 -6.000000 -6.000000 -5.000000
# ...            ...  ...       ...       ...       ...       ...       ...
# 43793            0  ... -4.111599 -3.000000 -4.000000 -3.000000 -3.000000
# 43794            0  ... -2.995268 -4.111599 -3.000000 -4.000000 -3.000000
# 43795            0  ... -4.123623 -2.995268 -4.111599 -3.000000 -4.000000
# 43796            0  ... -2.927048 -4.123623 -2.995268 -4.111599 -3.000000
# 43797            0  ... -4.119015 -2.927048 -4.123623 -2.995268 -4.111599
#
#         Iws_1   Iws_2   Iws_3   Iws_4   Iws_5
# 24       6.25    5.36    3.57    2.68    1.79
# 25       7.14    6.25    5.36    3.57    2.68
# 26       8.93    7.14    6.25    5.36    3.57
# 27      10.72    8.93    7.14    6.25    5.36
# 28      12.51   10.72    8.93    7.14    6.25
# ...       ...     ...     ...     ...     ...
# 43793  249.85  249.85  246.72  242.70  237.78
# 43794  249.85  249.85  249.85  246.72  242.70
# 43795  249.85  249.85  249.85  249.85  246.72
# 43796  249.85  249.85  249.85  249.85  249.85
# 43797  249.85  249.85  249.85  249.85  249.85
#
# [43766 rows x 36 columns]

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.333)

# %% [markdown]
# ## Modeling

# %%
linear = LinearRegression()
linear.fit(Xtrain, ytrain)
linear.score(Xtrain, ytrain)
# Out:
# 0.9751546344793383

# %%
ytest = ytest.values

# %%
def cal():
    data = [0] * 3
    for i in range(len(predict)):
        for j in range(3):
            data[j] += abs(predict[i][j] - ytest[i][j])
    for i in range(3):
        data[i] /= len(predict)
    return (data[0], data[1], data[2])

# %%
predict = linear.predict(Xtest)
print('R^2 score:', r2_score(predict, ytest))
print('Mean Absolute Error:', mean_absolute_error(predict, ytest))
# Out:
# R^2 score: 0.9742740823370429
# Mean Absolute Error: 4.632570053575127

# %%
cal()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-0b9011992b43> in <module>
# ----> 1 cal()
#
# <ipython-input-23-10bb6e9a46be> in cal()
#       3     for i in range(len(predict)):
#       4         for j in range(3):
# ----> 5             data[j] += abs(predict[i][j] - ytest[i][j])
#       6     for i in range(3):
#       7         data[i] /= len(predict)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0

# %%
sum([12.220328459541111, 0.8129828010090021, 0.8342715266273949]) / 3
# Out:
# 4.6225275957258365

# %% [markdown]
# ## Predict for next 6 hours

# %%
for i in range(6):
    tail = pd.concat([df.tail(1)], ignore_index=True)
    tail.loc[:, ['day', 'month', 'year', 'hour']] = [1, 1, 2015, i]
    df = pd.concat([df, tail], ignore_index=True)
    df.loc[len(df) - 1:, predicts] = linear.predict(tail[features])
    for var in need_shift:
        for i in range(1, 6):
            key = var + '_' + str(i)
            df[key] = df[var].shift(periods=i)

# %%
df.tail(6)[['day', 'month', 'year', 'hour'] + predicts]
# Out:
#        day  month  year  hour      pm2.5       DEWP      TEMP
# 43766    1      1  2015     0  -2.088283 -22.579061 -4.129737
# 43767    1      1  2015     1  21.087569 -21.679392 -2.796999
# 43768    1      1  2015     2  -6.407150 -22.660888 -4.171412
# 43769    1      1  2015     3  25.381166 -21.731241 -2.788933
# 43770    1      1  2015     4 -11.609362 -22.739088 -4.238434
# 43771    1      1  2015     5  30.917628 -21.754491 -2.799485

# %% [markdown]
# - season
# - trend
# - statistical models for time serries
# - how data transform by times (up or down, low or high)
# - past data for weekdays or for pm2.5 last year
